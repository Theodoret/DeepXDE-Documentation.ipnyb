# %% [markdown]
# **Diffusion equation**
#
# Retyped by Theodoret Putra Agatho on 5 Aug. 2023
#
# [Source](https://deepxde.readthedocs.io/en/latest/demos/pinn_forward/diffusion.1d.html)

# %%
pip install deepxde
# Out:
# Requirement already satisfied: deepxde in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from deepxde) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.2.2)
# Requirement already satisfied: scikit-optimize>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from deepxde) (0.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.3.1)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize>=0.9.0->deepxde) (23.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->deepxde) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)

# %% [markdown]
# **Problem setup**
#
# We will solve a diffusion equation:
#
# \begin{align}
#         \frac{\partial y}{\partial t} = \frac{\partial ^2 y}{\partial x^2} - e^{-t} (sin(\pi x) - \pi ^2 sin((\pi x)), x \in [-1,1], t \in [0,1]
#     \end{align}
#
# with the initial condition
#
# \begin{align}
#         y(x, 0) = sin(\pi x).
#     \end{align}
#
# The reference solution is $y = e^{-t}sin(\pi x)$.

# %% [markdown]
# **Implementation**
#
# This description goes through the implementation of a solver for the above described diffusion equation step-by-step.
#
# First, the DeepXDE, NumPy (`np`), and TensorFlow (`tf`) modules are imported:

# %%
import deepxde as dde
import numpy as np
from deepxde.backend import tf
# Out:
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %% [markdown]
# We begin by defining computational geometries. We can use a built-in-class `interval` and `TimeDomain` and we combine both the domains using `GeometryXTime` as follows

# %%
geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

# %% [markdown]
# Next, we express the PDE residual of the diffusion equation:

# %%
def pde(x, y):
  dy_t = dde.grad.jacobian(y, x, j=1)
  dy_xx = dde.grad.hessian(y, x, j=0)
  return (
      dy_t
      - dy_xx
      + tf.exp(-x[:, 1:])
      * (tf.sin(np.pi * x[:, 0:1]) - np.pi ** 2 * tf.sin(np.pi * x[:, 0:1]))
  )

# %% [markdown]
# The first argument to `pde` is 2-dimenasional vector where the first component(`x[:,0:1]`) is $x$-coordinate and the second component(`x[:,1:]`) is the $t$-coordinate. The second argument is the network output, i.e., the solution $y(x, t)$.
#
# Next, we consider the boundary/initial condition. First, solution `func` is defined as:

# %%
def func(x):
  return np.sin(np.pi * x[:, 0:1]) * np.exp(-x[:, 1:])

# %% [markdown]
# `on_boundary` is chosen here to use the whole boundary of the computational domain as the boundary condition. We include the `geotime` space, time geommetry created above and `on_boundary` as the BC in the `DirichletBC` function of DeepXDE. We also define `IC` which is the initial conditon for the diffusion equation and we use the computational domain, initial function, and `on_initial` to specify the IC.

# %%
bc = dde.icbc.DirichletBC(geomtime, func, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(geomtime, func, lambda _, on_initial: on_initial)

# %% [markdown]
# Now, we have specified the geometry, the PDE residual and the boundary/initial conditions. We then define `TimePDE` problem as

# %%
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc, ic],
    num_domain=40,
    num_boundary=20,
    num_initial=10,
    solution=func,
    num_test=10000,
)
# Out:
# Warning: 10000 points required, but 10082 points sampled.

# %% [markdown]
# The number 40 is the number of training residual points sampled inside the domain, and the number 20 is the number of training points sampled on the boundary (the left and right endpoints of the interval). We also include 10 initial residual points for the initial conditions and 10000 points for testing the PDE residual.
#
# Next, we choose the network. Here, we use a fully connected neural network of depth 4 (i.e., 3 hidden layers and width 32:

# %%
layer_size = [2] + [32] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

# %% [markdown]
# Now, we have the PDE problem and the network. We build a `Model` and choose the optimizer and learning rate. We then train the model for 10000 iterations.

# %%
model = dde.Model(data, net)
model.compile("adam", lr=0.001, metrics=["l2 relative error"])
losshistory, train_state = model.train(iterations=10000)
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.157773 s
# /usr/local/lib/python3.10/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:116: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 1.518934 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.63e+01, 2.18e-01, 6.76e-01]    [1.77e+01, 2.18e-01, 6.76e-01]    [1.53e+00]
# 1000      [5.00e-03, 6.27e-03, 1.36e-03]    [1.02e-02, 6.27e-03, 1.36e-03]    [1.51e-01]
# 2000      [7.30e-04, 8.01e-04, 2.06e-04]    [2.30e-03, 8.01e-04, 2.06e-04]    [5.45e-02]
# 3000      [2.43e-04, 1.48e-04, 5.07e-05]    [1.34e-03, 1.48e-04, 5.07e-05]    [2.11e-02]
# 4000      [1.63e-04, 4.32e-05, 2.44e-05]    [9.53e-04, 4.32e-05, 2.44e-05]    [1.10e-02]
# 5000      [1.59e-03, 1.22e-04, 4.06e-05]    [1.39e-03, 1.22e-04, 4.06e-05]    [1.41e-02]
# 6000      [1.18e-04, 9.27e-06, 1.39e-05]    [4.97e-04, 9.27e-06, 1.39e-05]    [5.47e-03]
# 7000      [7.96e-05, 4.62e-06, 1.04e-05]    [4.23e-04, 4.62e-06, 1.04e-05]    [4.23e-03]
# 8000      [1.55e-03, 9.98e-05, 4.39e-05]    [9.68e-04, 9.98e-05, 4.39e-05]    [1.29e-02]
# 9000      [4.82e-05, 3.15e-06, 8.37e-06]    [3.18e-04, 3.15e-06, 8.37e-06]    [3.43e-03]
# 10000     [3.96e-05, 2.77e-06, 8.21e-06]    [2.76e-04, 2.77e-06, 8.21e-06]    [3.34e-03]
#
# Best model at step 10000:
#   train loss: 5.06e-05
#   test loss: 2.87e-04
#   test metric: [3.34e-03]
#
# 'train' took 29.274703 s

# %% [markdown]
# We also save and plot the best trained result and loss history.

# %%
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
